# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
power_plant = pd.read_csv(r"C:\Users\sanjiv\Documents\Datasets\World Resources Institute\globalpowerplantdatabasev120\global_power_plant_database.csv")

# %%
power_plant.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538        33.00   32.3220    65.1190        Hydro         NaN
# 1  GEODB0040541        66.00   34.5560    69.4787        Hydro         NaN
# 2  GEODB0040534       100.00   34.6410    69.7170        Hydro         NaN
# 3  GEODB0040536        11.55   34.4847    70.3633        Hydro         NaN
# 4  GEODB0040540        42.00   34.5638    69.1134          Gas         NaN
#
# ...

# %%
power_plant.shape
# Out:
# (29910, 24)

# %%
power_plant.isnull().sum()
# Out:
# country                         0
# country_long                    0
# name                            0
# gppd_idnr                       0
# capacity_mw                     0
# latitude                        0
# longitude                       0
# primary_fuel                    0
# other_fuel1                 27947
# other_fuel2                 29607
# other_fuel3                 29806
# commissioning_year          13607
# owner                       10379
# source                         15
# url                            18
# geolocation_source            419
# wepp_id                     13529
# year_of_capacity_data       16167
# generation_gwh_2013         22914
# generation_gwh_2014         22470
# generation_gwh_2015         21766
# generation_gwh_2016         20939
# generation_gwh_2017         20697
# estimated_generation_gwh     8119
# dtype: int64

# %%
# Drop unnecessary columns
power_plant.drop(['gppd_idnr','owner','source','url','geolocation_source','wepp_id','estimated_generation_gwh'], axis=1, inplace=True)

# %%
power_plant.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#    capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0        33.00   32.3220    65.1190        Hydro         NaN         NaN
# 1        66.00   34.5560    69.4787        Hydro         NaN         NaN
# 2       100.00   34.6410    69.7170        Hydro         NaN         NaN
# 3        11.55   34.4847    70.3633        Hydro         NaN         NaN
# 4        42.00   34.5638    69.1134          Gas         NaN         NaN
#
#   other_fuel3  commissioning_year  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
power_plant.columns
# Out:
# Index(['country', 'country_long', 'name', 'capacity_mw', 'latitude',
#        'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017'],
#       dtype='object')

# %%
power_plant[power_plant['country_long']=='India']['name'].nunique()
# Out:
# 861

# %%
power_plant[(power_plant['country_long']=="India") & (power_plant['primary_fuel']=='Solar')]['capacity_mw'].sum()
# Out:
# 2529.5

# %%
#power_plant
#power_plant = power_plant.groupby(by='country_long').sum()

# %%
power_plant.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#    capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0        33.00   32.3220    65.1190        Hydro         NaN         NaN
# 1        66.00   34.5560    69.4787        Hydro         NaN         NaN
# 2       100.00   34.6410    69.7170        Hydro         NaN         NaN
# 3        11.55   34.4847    70.3633        Hydro         NaN         NaN
# 4        42.00   34.5638    69.1134          Gas         NaN         NaN
#
#   other_fuel3  commissioning_year  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
plt.figure(figsize=(20,10));
power_plant['capacity_mw'].sort_values(ascending=False).head(10).plot(kind='bar', stacked=False, figsize=(20,10), width=0.75)
plt.xticks(rotation = 45);

# %%
a = dict(power_plant[power_plant['country_long']=='Bahrain']['primary_fuel'].value_counts())

# %%
print(a.values())
# Out:
# dict_values([6, 1])

# %%
a = dict(power_plant[power_plant['country_long']=='India']['primary_fuel'].value_counts())

# %%
import bokeh

# %%
bokeh.__version__
# Out:
# '1.3.4'

# %%
import bokeh.palettes

# %%
bokeh.palettes.Category20
# Out:
# {3: ['#1f77b4', '#aec7e8', '#ff7f0e'],
#  4: ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78'],
#  5: ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c'],
#  6: ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a'],
#  7: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
#   '#2ca02c',
#   '#98df8a',
#   '#d62728'],
#  8: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
#   '#2ca02c',
#   '#98df8a',
#   '#d62728',
#   '#ff9896'],
#  9: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
#   '#2ca02c',
#   '#98df8a',
#   '#d62728',
#   '#ff9896',
#   '#9467bd'],
#  10: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
#   '#2ca02c',
#   '#98df8a',
#   '#d62728',
#   '#ff9896',
#   '#9467bd',
#   '#c5b0d5'],
#  11: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
#   '#2ca02c',
#   '#98df8a',
#   '#d62728',
#   '#ff9896',
#   '#9467bd',
#   '#c5b0d5',
#   '#8c564b'],
#  12: ['#1f77b4',
#   '#aec7e8',
#   '#ff7f0e',
#   '#ffbb78',
# ...

# %%
power_plant[power_plant['country_long']=='India']
# Out:
#       country country_long                          name  capacity_mw  \
# 12088     IND        India              ACME Solar Tower          2.5
# 12089     IND        India           ADITYA CEMENT WORKS         98.0
# 12090     IND        India      AES Saurashtra Windfarms         39.2
# 12091     IND        India                   AGARTALA GT        135.0
# 12092     IND        India                  AKALTARA TPP       1800.0
# ...       ...          ...                           ...          ...
# 12944     IND        India                  YERMARUS TPP       1600.0
# 12945     IND        India  Yelesandra Solar Power Plant          3.0
# 12946     IND        India  Yelisirur wind power project         25.5
# 12947     IND        India                   ZAWAR MINES         80.0
# 12948     IND        India       iEnergy Theni Wind Farm         16.5
#
#        latitude  longitude primary_fuel other_fuel1 other_fuel2 other_fuel3  \
# ...

# %%
def getinfo(_df, _name):
    return (_df[_df['country_long']==_name].groupby(by='primary_fuel').sum())['capacity_mw']/1000

# %%
b = getinfo(power_plant, 'India')

# %%
b
# Out:
# primary_fuel
# Biomass      1.003260
# Coal       200.503220
# Gas         24.898871
# Hydro       45.451270
# Nuclear      8.780000
# Oil          1.880840
# Solar        2.529500
# Wind         3.647150
# Name: capacity_mw, dtype: float64

# %%
power_plant.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#    capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0        33.00   32.3220    65.1190        Hydro         NaN         NaN
# 1        66.00   34.5560    69.4787        Hydro         NaN         NaN
# 2       100.00   34.6410    69.7170        Hydro         NaN         NaN
# 3        11.55   34.4847    70.3633        Hydro         NaN         NaN
# 4        42.00   34.5638    69.1134          Gas         NaN         NaN
#
#   other_fuel3  commissioning_year  year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
def top5(_df, current_country_name):
    return _df[_df['country_long']==current_country_name]['generation_gwh_2013'].sort_values(ascending=False).head(5)

# %%
x = top5(power_plant, 'India')
print(x)
# Out:
# 12558    27586.20
# 12924    26761.39
# 12559    21973.00
# 12832    20347.00
# 12439    19353.00
# Name: generation_gwh_2013, dtype: float64

# %%
from bokeh.io import show
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ['2015', '2016', '2017']

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 3, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

source = ColumnDataSource(data=data)

p = figure(y_range=fruits, x_range=(0, 10), plot_width=250, plot_height = 250, title="Fruit Counts by Year",
           toolbar_location=None, tools="hover")

p.hbar(y=[dodge('fruits', 0, range=p.y_range)], right='2015', height=0.2, source=source)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-95-fd9f2a6990ba> in <module>
#      17            toolbar_location=None, tools="hover")
#      18
# ---> 19 p.hbar(y=[1,2,3,4,5,6], right='2015', height=0.2, source=source)
#      20
#      21
#
# fakesource in hbar(self, y, height, right, left, **kwargs)
#
# ~\Anaconda3\lib\site-packages\bokeh\plotting\helpers.py in func(self, **kwargs)
#     832         incompatible_literal_spec_values += _process_sequence_literals(glyphclass, glyph_ca, source, is_user_source)
#     833         if incompatible_literal_spec_values:
# --> 834             raise RuntimeError(_GLYPH_SOURCE_MSG % nice_join(incompatible_literal_spec_values, conjuction="and"))
#     835
#     836         # handle the nonselection glyph, we always set one
#
# RuntimeError:
#
# Expected y to reference fields in the supplied data source.
#
# ...

# %%
show(p)
