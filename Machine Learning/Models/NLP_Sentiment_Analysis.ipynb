# %% [markdown]
# # NLP Sentiment Analysis

# %%
import pandas as pd
import numpy as np
import re
from nltk import word_tokenize, sent_tokenize, wordpunct_tokenize
from nltk.stem import SnowballStemmer, PorterStemmer
from nltk.corpus import stopwords

# %% [markdown]
# Download the `nltk` resources `punkt`, `wordnet` and `stopwords`

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sanjiv\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
csv_file = r"C:\Users\sanjiv\Documents\Datasets\NLP\NLP_Case_Study\Data.csv"
tweet_data = pd.read_csv(csv_file)

# %%
tweet_data.head()
# Out:
#    tweet_id sentiment        name  \
# 0         1   neutral     cairdin
# 1         2  positive    jnardino
# 2         3   neutral  yvonnalynn
# 3         4  negative    jnardino
# 4         5  negative    jnardino
#
#                                                 text   tweet_created  \
# 0                               What @dhepburn said.  24/02/15 11:35
# 1  plus you've added commercials to the experienc...  24/02/15 11:15
# 2  I didn't today... Must mean I need to take ano...  24/02/15 11:15
# 3  it's really aggressive to blast obnoxious "ent...  24/02/15 11:15
# 4           and it's a really big bad thing about it  24/02/15 11:14
#
#   tweet_location               user_timezone
# 0            NaN  Eastern Time (US & Canada)
# 1            NaN  Pacific Time (US & Canada)
# 2      Lets Play  Central Time (US & Canada)
# 3            NaN  Pacific Time (US & Canada)
# 4            NaN  Pacific Time (US & Canada)

# %% [markdown]
# ### Tokenize and clean the tweets
#
# Pre-process the tweets in the following order
# - sentence tokens using `sent_tokenize()`
# - clean the tokens formed by using `re` library
# - token the cleaned token into word token using `word_tokenize()`

# %%
def sent_tokenize_tweets(tweet_column):
    sent_tweet_column = []
    
    for line in tweet_column:
        _token = sent_tokenize(line)
        if _token != '':
            sent_tweet_column.append(_token)
    
    return sent_tweet_column

# %%
def clean_tweets(tweets):
    
    cleaned_tweets = []
    
    for _tweet in tweets:
        # remove html tags, if any
        new_tweet = re.sub('[<._*?>]+', '', _tweet[0])
        
        # remove URLs
        new_tweet = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', new_tweet)
        
        # remove Twitter handles
        new_tweet = re.sub("(@[A-Za-z0-9_]+)","", new_tweet)
        
        # remove punctuation 
        new_tweet = re.sub(r'[^\w\s]', '', new_tweet)
        
        # remove numbers
        new_tweet = re.sub(r'\d+','',new_tweet)
        
        # change to lower case
        new_tweet = new_tweet.lower()
        
        if new_tweet !='':
            cleaned_tweets.append(new_tweet)
            
    return cleaned_tweets

# %%
def word_tokenize_tweets(cleaned_tweets):
    word_tweet_column=[]
    
    for tweet in cleaned_tweets:
        word_token = word_tokenize(tweet)
        
        if word_token != '':
            word_tweet_column.append(word_token)
            
    return word_tweet_column

# %%
a = sent_tokenize_tweets(tweet_data['text'])

# %%
b = clean_tweets(a)

# %%
c = word_tokenize_tweets(b)

# %% [markdown]
# ### Stemming
# Normalize the tweet data

# %%
snowball = SnowballStemmer(language='english')
porter = PorterStemmer()

# %%
def stem_tweets(processed_words):
    stemmed_words = []
    stop_words = set(stopwords.words('english'))
    for words in processed_words:
        #stemmed_words.append(snowball.stem(word))
        print(words)
        print([snowball.stem(each_word) for each_word in words if not each_word in stop_words])
        #print('------------------------------------------')
        #print([porter.stem(each_word) for each_word in words])
        print('==========================================')

# %%
d = stem_tweets(c)
# Out:
# ['what', 'said']
# ['said']
# ==========================================
# ['plus', 'youve', 'added', 'commercials', 'to', 'the', 'experience', 'tacky']
# ['plus', 'youv', 'ad', 'commerci', 'experi', 'tacki']
# ==========================================
# ['i', 'didnt', 'today', 'must', 'mean', 'i', 'need', 'to', 'take', 'another', 'trip']
# ['didnt', 'today', 'must', 'mean', 'need', 'take', 'anoth', 'trip']
# ==========================================
# ['its', 'really', 'aggressive', 'to', 'blast', 'obnoxious', 'entertainment', 'in', 'your', 'guests', 'faces', 'amp', 'they', 'have', 'little', 'recourse']
# ['realli', 'aggress', 'blast', 'obnoxi', 'entertain', 'guest', 'face', 'amp', 'littl', 'recours']
# ==========================================
# ['and', 'its', 'a', 'really', 'big', 'bad', 'thing', 'about', 'it']
# ['realli', 'big', 'bad', 'thing']
# ==========================================
# ['seriously', 'would', 'pay', 'a', 'flight', 'for', 'seats', 'that', 'didnt', 'have', 'this', 'playing']
# ['serious', 'would', 'pay', 'flight', 'seat', 'didnt', 'play']
# ==========================================
# ['yes', 'nearly', 'every', 'time', 'i', 'fly', 'vx', 'this', 'ar', 'worm', 'won', 'go', 'away']
# ['yes', 'near', 'everi', 'time', 'fli', 'vx', 'ar', 'worm', 'go', 'away']
# ==========================================
# ['really', 'missed', 'a', 'prime', 'opportunity', 'for', 'men', 'without', 'hats', 'parody', 'there']
# ['realli', 'miss', 'prime', 'opportun', 'men', 'without', 'hat', 'parodi']
# ==========================================
# ['well', 'i', 'didntbut', 'now', 'i', 'do']
# ['well', 'didntbut']
# ==========================================
# ['it', 'was', 'amazing', 'and', 'arrived', 'an', 'hour', 'early']
# ['amaz', 'arriv', 'hour', 'earli']
# ==========================================
# ['did', 'you', 'know', 'that', 'suicide', 'is', 'the', 'second', 'leading', 'cause', 'of', 'death', 'among', 'teens']
# ['know', 'suicid', 'second', 'lead', 'caus', 'death', 'among', 'teen']
# ==========================================
# ['i', 'lt', 'pretty', 'graphics']
# ['lt', 'pretti', 'graphic']
# ==========================================
# ['this', 'is', 'such', 'a', 'great', 'deal']
# ['great', 'deal']
# ==========================================
# ['im', 'flying', 'your', 'fabulous', 'seductive', 'skies', 'again']
# ['im', 'fli', 'fabul', 'seduct', 'sky']
# ==========================================
# ['thanks']
# ['thank']
# ==========================================
# ['sfopdx', 'schedule', 'is', 'still', 'mia']
# ['sfopdx', 'schedul', 'still', 'mia']
# ==========================================
# ['so', 'excited', 'for', 'my', 'first', 'cross', 'country', 'flight', 'lax', 'to', 'mco', 'ive', 'heard', 'nothing', 'but', 'great', 'things', 'about', 'virgin', 'america']
# ['excit', 'first', 'cross', 'countri', 'flight', 'lax', 'mco', 'ive', 'heard', 'noth', 'great', 'thing', 'virgin', 'america']
# ==========================================
# ['i', 'flew', 'from', 'nyc', 'to', 'sfo', 'last', 'week', 'and', 'couldnt', 'fully', 'sit', 'in', 'my', 'seat', 'due', 'to', 'two', 'large', 'gentleman', 'on', 'either', 'side', 'of', 'me']
# ['flew', 'nyc', 'sfo', 'last', 'week', 'couldnt', 'fulli', 'sit', 'seat', 'due', 'two', 'larg', 'gentleman', 'either', 'side']
# ==========================================
# ['flying']
# ['fli']
# ==========================================
# ['you', 'know', 'what', 'would', 'be', 'amazingly', 'awesome']
# ['know', 'would', 'amaz', 'awesom']
# ==========================================
# ['why', 'are', 'your', 'first', 'fares', 'in', 'may', 'over', 'three', 'times', 'more', 'than', 'other', 'carriers', 'when', 'all', 'seats', 'are', 'available', 'to', 'select']
# ['first', 'fare', 'may', 'three', 'time', 'carrier', 'seat', 'avail', 'select']
# ==========================================
# ['i', 'love', 'this', 'graphic']
# ['love', 'graphic']
# ==========================================
# ['i', 'love', 'the', 'hipster', 'innovation']
# ['love', 'hipster', 'innov']
# ==========================================
# ['will', 'you', 'be', 'making', 'bosgtlas', 'non', 'stop', 'permanently', 'anytime', 'soon']
# ['make', 'bosgtla', 'non', 'stop', 'perman', 'anytim', 'soon']
# ==========================================
# ['you', 'guys', 'messed', 'up', 'my', 'seating']
# ['guy', 'mess', 'seat']
# ==========================================
# ['status', 'match', 'program']
# ['status', 'match', 'program']
# ==========================================
# ['what', 'happened', 'ur', 'vegan', 'food', 'options']
# ['happen', 'ur', 'vegan', 'food', 'option']
# ==========================================
# ['do', 'you', 'miss', 'me']
# ['miss']
# ==========================================
# ['amazing', 'to', 'me', 'that', 'we', 'cant', 'get', 'any', 'cold', 'air', 'from', 'the', 'vents']
# ['amaz', 'cant', 'get', 'cold', 'air', 'vent']
# ==========================================
# ['lax', 'to', 'ewr', 'middle', 'seat', 'on', 'a', 'red', 'eye']
# ['lax', 'ewr', 'middl', 'seat', 'red', 'eye']
# ==========================================
# ['hi']
# ['hi']
# ==========================================
# ['are', 'the', 'hours', 'of', 'operation', 'for', 'the', 'club', 'at', 'sfo', 'that', 'are', 'posted', 'online', 'current']
# ['hour', 'oper', 'club', 'sfo', 'post', 'onlin', 'current']
# ==========================================
# ['help', 'left', 'expensive', 'headphones', 'on', 'flight', 'iad', 'to', 'lax', 'today']
# ['help', 'left', 'expens', 'headphon', 'flight', 'iad', 'lax', 'today']
# ==========================================
# ['awaiting', 'my', 'return', 'phone', 'call', 'just', 'would', 'prefer', 'to', 'use', 'your', 'online', 'selfservice', 'option']
# ['await', 'return', 'phone', 'call', 'would', 'prefer', 'use', 'onlin', 'selfservic', 'option']
# ==========================================
# ['this', 'is', 'great', 'news']
# ['great', 'news']
# ==========================================
# ['rt', 'vibe', 'with', 'the', 'moodlight', 'from', 'takeoff', 'to', 'touchdown']
# ['rt', 'vibe', 'moodlight', 'takeoff', 'touchdown']
# ==========================================
# ['moodlighting', 'is', 'the', 'only', 'way', 'to', 'fly']
# ['moodlight', 'way', 'fli']
# ==========================================
# ['done', 'and', 'done']
# ['done', 'done']
# ==========================================
# ['when', 'can', 'i', 'book', 'my', 'flight', 'to', 'hawaii']
# ['book', 'flight', 'hawaii']
# ==========================================
# ['your', 'chat', 'support', 'is', 'not', 'working', 'on', 'your', 'site']
# ['chat', 'support', 'work', 'site']
# ==========================================
# ['view', 'of', 'downtown', 'los', 'angeles', 'the', 'hollywood', 'sign', 'and', 'beyond', 'that', 'rain', 'in', 'the', 'mountains']
# ['view', 'downtown', 'los', 'angel', 'hollywood', 'sign', 'beyond', 'rain', 'mountain']
# ==========================================
# ['hey', 'first', 'time', 'flyer', 'next', 'week', 'excited']
# ['hey', 'first', 'time', 'flyer', 'next', 'week', 'excit']
# ==========================================
# ['plz', 'help', 'me', 'win', 'my', 'bid', 'upgrade', 'for', 'my', 'flight', 'laxgtsea']
# ['plz', 'help', 'win', 'bid', 'upgrad', 'flight', 'laxgtsea']
# ==========================================
# ['i', 'have', 'an', 'unused', 'ticket', 'but', 'moved', 'to', 'a', 'new', 'city', 'where', 'you', 'dont', 'fly']
# ['unus', 'ticket', 'move', 'new', 'citi', 'dont', 'fli']
# ==========================================
# ['are', 'flights', 'leaving', 'dallas', 'for', 'seattle', 'on', 'time', 'feb']
# ['flight', 'leav', 'dalla', 'seattl', 'time', 'feb']
# ==========================================
# ['im', 'elevategold', 'for', 'a', 'good', 'reason', 'you', 'rock']
# ['im', 'elevategold', 'good', 'reason', 'rock']
# ==========================================
# ['dream']
# ['dream']
# ==========================================
# ['wow', 'this', 'just', 'blew', 'my', 'mind']
# ['wow', 'blew', 'mind']
# ==========================================
# ['after', 'last', 'night', 'tribute', 'soundofmusic', 'oscars']
# ['last', 'night', 'tribut', 'soundofmus', 'oscar']
# ==========================================
# ['all', 'were', 'entertaining']
# ['entertain']
# ==========================================
# ['is', 'flight', 'on', 'its', 'way']
# ['flight', 'way']
# ==========================================
# ['julie', 'andrews', 'all', 'the', 'way', 'though', 'was', 'very', 'impressive']
# ['juli', 'andrew', 'way', 'though', 'impress']
# ==========================================
# ['wish', 'you', 'flew', 'out', 'of', 'atlanta']
# ['wish', 'flew', 'atlanta']
# ==========================================
# ['julie', 'andrews']
# ['juli', 'andrew']
# ==========================================
# ['will', 'flights', 'be', 'leaving', 'dallas', 'for', 'la', 'on', 'february', 'th']
# ['flight', 'leav', 'dalla', 'la', 'februari', 'th']
# ==========================================
# ['hi']
# ['hi']
# ==========================================
# ['you', 'know', 'it']
# ['know']
# ==========================================
# ['im', 'lady', 'gaga']
# ['im', 'ladi', 'gaga']
# ==========================================
# ['carrie']
# ['carri']
# ==========================================
# ['new', 'marketing', 'song']
# ['new', 'market', 'song']
# ==========================================
# ['julie', 'andrews', 'first', 'but', 'lady', 'gaga', 'wowd', 'me', 'last', 'night']
# ['juli', 'andrew', 'first', 'ladi', 'gaga', 'wowd', 'last', 'night']
# ==========================================
# ['i', 'called', 'a', 'weeks', 'ago', 'about', 'adding', 'flights', 'from', 'to', 'my', 'elevatethey', 'still', 'havent', 'shown', 'uphelp']
# ['call', 'week', 'ago', 'ad', 'flight', 'elevatethey', 'still', 'havent', 'shown', 'uphelp']
# ==========================================
# ['all', 'are', 'great', 'but', 'i', 'have', 'to', 'go', 'with', 'carrieunderwood']
# ['great', 'go', 'carrieunderwood']
# ==========================================
# ['sorry', 'mary', 'martin', 'had', 'it', 'first']
# ['sorri', 'mari', 'martin', 'first']
# ==========================================
# ['love', 'all', 'three', 'but', 'you', 'really', 'cant', 'beat', 'the', 'classics']
# ['love', 'three', 'realli', 'cant', 'beat', 'classic']
# ==========================================
# ['flight', 'dal', 'to', 'dca', 'pm']
# ['flight', 'dal', 'dca', 'pm']
# ==========================================
# ['heyyyy', 'guyyyys', 'been', 'trying', 'to', 'get', 'through', 'for', 'an', 'hour']
# ['heyyyi', 'guyyyi', 'tri', 'get', 'hour']
# ==========================================
# ['hi', 'virgin']
# ['hi', 'virgin']
# ==========================================
# ['congrats', 'on', 'winning', 'the', 'award', 'for', 'best', 'deals', 'from', 'an', 'airline', 'us']
# ['congrat', 'win', 'award', 'best', 'deal', 'airlin', 'us']
# ==========================================
# ['everything', 'was', 'fine', 'until', 'you', 'lost', 'my', 'bag']
# ['everyth', 'fine', 'lost', 'bag']
# ==========================================
# ['need', 'to', 'change', 'reservation']
# ['need', 'chang', 'reserv']
# ==========================================
# ['i', 'emailed', 'your', 'customer', 'service', 'team']
# ['email', 'custom', 'servic', 'team']
# ==========================================
# ['hi', 'i', 'just', 'booked', 'a', 'flight', 'but', 'need', 'to', 'add', 'baggage', 'how', 'can', 'i', 'do', 'this']
# ['hi', 'book', 'flight', 'need', 'add', 'baggag']
# ==========================================
# ['your', 'airline', 'is', 'awesome', 'but', 'your', 'lax', 'loft', 'needs', 'to', 'step', 'up', 'its', 'game']
# ['airlin', 'awesom', 'lax', 'loft', 'need', 'step', 'game']
# ==========================================
# ['not', 'worried', 'its', 'been', 'a', 'great', 'ride', 'in', 'a', 'new', 'plane', 'with', 'great', 'crew']
# ['worri', 'great', 'ride', 'new', 'plane', 'great', 'crew']
# ==========================================
# ['awesome']
# ['awesom']
# ==========================================
# ['or', 'watch', 'some', 'of', 'the', 'best', 'student', 'films', 'in', 'the', 'country', 'at', 'feet']
# ['watch', 'best', 'student', 'film', 'countri', 'feet']
# ==========================================
# ['first', 'time', 'flying', 'you', 'all']
# ['first', 'time', 'fli']
# ==========================================
# ['what', 'is', 'going', 'on', 'with', 'customer', 'service']
# ['go', 'custom', 'servic']
# ==========================================
# ['what', 'happened', 'to', 'doom']
# ['happen', 'doom']
# ==========================================
# ['why', 'cant', 'you', 'supp', 'the', 'biz', 'traveler', 'like', 'and', 'have', 'customer', 'service', 'like', 'neverflyvirginforbusiness']
# ['cant', 'supp', 'biz', 'travel', 'like', 'custom', 'servic', 'like', 'neverflyvirginforbusi']
# ==========================================
# ['ive', 'applied', 'more', 'then', 'once', 'to', 'be', 'a', 'member', 'of', 'the', 'inflight', 'crew', 'teamim', 'interested']
# ['ive', 'appli', 'member', 'inflight', 'crew', 'teamim', 'interest']
# ==========================================
# ['youre', 'the', 'best']
# ['your', 'best']
# ==========================================
# ['i', 'have', 'no', 'interesting', 'flying', 'with', 'you', 'after', 'this']
# ['interest', 'fli']
# ==========================================
# ['it', 'was', 'a', 'disappointing', 'experience', 'which', 'will', 'be', 'shared', 'with', 'every', 'business', 'traveler', 'i', 'meet']
# ['disappoint', 'experi', 'share', 'everi', 'busi', 'travel', 'meet']
# ==========================================
# ['i', 'having', 'trouble', 'adding', 'this', 'flight', 'my', 'wife', 'booked', 'to', 'my', 'elevate', 'account']
# ['troubl', 'ad', 'flight', 'wife', 'book', 'elev', 'account']
# ==========================================
# ['cant', 'bring', 'up', 'my', 'reservation', 'online', 'using', 'flight', 'booking', 'problems', 'code']
# ['cant', 'bring', 'reserv', 'onlin', 'use', 'flight', 'book', 'problem', 'code']
# ==========================================
# ['random', 'q', 'whats', 'the', 'distribution', 'of', 'elevate', 'avatars']
# ['random', 'q', 'what', 'distribut', 'elev', 'avatar']
# ==========================================
# ['i', 'lt', 'flying', 'va', 'but', 'life', 'happens', 'and', 'i', 'am', 'trying', 'to', 'change', 'my', 'trip', 'jperhi', 'can', 'you', 'helpva', 'home', 'page', 'will', 'not', 'let', 'me']
# ['lt', 'fli', 'va', 'life', 'happen', 'tri', 'chang', 'trip', 'jperhi', 'helpva', 'home', 'page', 'let']
# ==========================================
# ['why', 'is', 'the', 'site', 'down']
# ['site']
# ==========================================
# ['you', 'down', 'with', 'rnp']
# ['rnp']
# ==========================================
# ['hi', 'i', 'did', 'not', 'get', 'points', 'on', 'my', 'elevate', 'account', 'for', 'my', 'most', 'recent', 'flight', 'how', 'do', 'i', 'add', 'the', 'flight', 'and', 'points', 'to', 'my', 'account']
# ['hi', 'get', 'point', 'elev', 'account', 'recent', 'flight', 'add', 'flight', 'point', 'account']
# ==========================================
# ['i', 'like', 'the', 'tv', 'and', 'interesting', 'video']
# ['like', 'tv', 'interest', 'video']
# ==========================================
# ['just', 'landed', 'in', 'lax', 'an', 'hour', 'after', 'i', 'should', 'of', 'been', 'here']
# ['land', 'lax', 'hour']
# ==========================================
# ['why', 'is', 'flight', 'redirected']
# ['flight', 'redirect']
# ==========================================
# ['is', 'it', 'me', 'or', 'is', 'your', 'website', 'down']
# ['websit']
# ==========================================
# ['i', 'cant', 'check', 'in', 'or', 'add', 'a', 'bag']
# ['cant', 'check', 'add', 'bag']
# ==========================================
# ['let', 'scanned', 'in', 'passengers', 'leave', 'the', 'plane', 'than', 'told', 'someone', 'to', 'remove', 'their', 'bag', 'from', 'st', 'class', 'bin']
# ['let', 'scan', 'passeng', 'leav', 'plane', 'told', 'someon', 'remov', 'bag', 'st', 'class', 'bin']
# ==========================================
# ['what', 'is', 'your', 'phone', 'number']
# ['phone', 'number']
# ==========================================
# ['is', 'anyone', 'doing', 'anything', 'there', 'today']
# ['anyon', 'anyth', 'today']
# ==========================================
# ['trying', 'to', 'add', 'my', 'boy', 'prince', 'to', 'my', 'ressie']
# ['tri', 'add', 'boy', 'princ', 'ressi']
# ==========================================
# ['why', 'must', 'a', 'traveler', 'miss', 'a', 'flight', 'to', 'late', 'flight', 'check', 'a', 'bag']
# ['must', 'travel', 'miss', 'flight', 'late', 'flight', 'check', 'bag']
# ==========================================
# ['check', 'out', 'new', 'music']
# ['check', 'new', 'music']
# ==========================================
# ['hows', 'a', 'direct', 'flight', 'fllgtsfo', 'have', 'unexpected', 'layover', 'in', 'vegas', 'fuel', 'yet', 'peeps', 'next', 'to', 'me', 'bought', 'for', 'vegas', 'flight']
# ['how', 'direct', 'flight', 'fllgtsfo', 'unexpect', 'layov', 'vega', 'fuel', 'yet', 'peep', 'next', 'bought', 'vega', 'flight']
# ==========================================
# ['your', 'no', 'late', 'flight', 'bag', 'check', 'just', 'lost', 'you', 'my', 'business']
# ['late', 'flight', 'bag', 'check', 'lost', 'busi']
# ==========================================
# ['amazing', 'customer', 'service', 'again']
# ['amaz', 'custom', 'servic']
# ==========================================
# ['called', 'your', 'service', 'line', 'and', 'was', 'hung', 'up', 'on']
# ['call', 'servic', 'line', 'hung']
# ==========================================
# ['your', 'site', 'is', 'tripping']
# ['site', 'trip']
# ==========================================
# ['i', 'was', 'scheduled', 'for', 'sfo', 'dal', 'flight', 'today']
# ['schedul', 'sfo', 'dal', 'flight', 'today']
# ==========================================
# ['has', 'getaway', 'deals', 'through', 'may', 'from', 'oneway']
# ['getaway', 'deal', 'may', 'oneway']
# ==========================================
# ['has', 'getaway', 'deals', 'through', 'may', 'from', 'oneway']
# ['getaway', 'deal', 'may', 'oneway']
# ==========================================
# ['has', 'getaway', 'deals', 'through', 'may', 'from', 'oneway']
# ['getaway', 'deal', 'may', 'oneway']
# ==========================================
# ['has', 'getaway', 'deals', 'through', 'may', 'from', 'oneway']
# ['getaway', 'deal', 'may', 'oneway']
# ==========================================
# ['have', 'a', 'great', 'week']
# ['great', 'week']
# ==========================================
# ['come', 'back', 'to', 'phl', 'already']
# ['come', 'back', 'phl', 'alreadi']
# ==========================================
# ['should', 'i', 'be', 'concerned', 'that', 'i', 'am', 'about', 'to', 'fly', 'on', 'a', 'plane', 'that', 'needs', 'to', 'be', 'delayed', 'due', 'to', 'a', 'tech', 'stop']
# ['concern', 'fli', 'plane', 'need', 'delay', 'due', 'tech', 'stop']
# ==========================================
# ['is', 'the', 'best', 'airline', 'i', 'have', 'flown', 'oneasy', 'to', 'change', 'your', 'reservationhelpful', 'representatives', 'amp', 'a', 'comfortable', 'flying', 'experience']
# ['best', 'airlin', 'flown', 'oneasi', 'chang', 'reservationhelp', 'repres', 'amp', 'comfort', 'fli', 'experi']
# ==========================================
# ['and', 'again']
# []
# ==========================================
# ['your', 'beautiful', 'frontend', 'design', 'is', 'down', 'right', 'now', 'but', 'it', 'was', 'cool', 'to', 'still', 'book', 'my', 'ticket', 'bc', 'all', 'your', 'backend', 'was', 'secure']
# ['beauti', 'frontend', 'design', 'right', 'cool', 'still', 'book', 'ticket', 'bc', 'backend', 'secur']
# ==========================================
# ['love', 'the', 'team', 'running', 'gate', 'e', 'at', 'las', 'tonight']
# ['love', 'team', 'run', 'gate', 'e', 'las', 'tonight']
# ==========================================
# ['use', 'another', 'browser']
# ['use', 'anoth', 'browser']
# ==========================================
# ['and', 'now', 'the', 'flight', 'flight', 'booking', 'problems', 'site', 'is', 'totally', 'down']
# ['flight', 'flight', 'book', 'problem', 'site', 'total']
# ==========================================
# ['i', 'like', 'the', 'customer', 'service', 'but', 'a', 'min', 'delay', 'just', 'for', 'connecting', 'passengers', 'seems', 'too', 'long']
# ['like', 'custom', 'servic', 'min', 'delay', 'connect', 'passeng', 'seem', 'long']
# ==========================================
# ['thanks', 'to', 'your', 'outstanding', 'nycjfk', 'crew', 'who', 'moved', 'mountains', 'to', 'get', 'me', 'home', 'to', 'san', 'francisco', 'tonight']
# ['thank', 'outstand', 'nycjfk', 'crew', 'move', 'mountain', 'get', 'home', 'san', 'francisco', 'tonight']
# ==========================================
# ['you', 'have', 'the', 'absolute', 'best', 'team', 'and', 'customer', 'service', 'ever']
# ['absolut', 'best', 'team', 'custom', 'servic', 'ever']
# ==========================================
# ['do', 'you', 'provide', 'complimentary', 'upgrades', 'to', 'first', 'class', 'if', 'there', 'are', 'available', 'seats']
# ['provid', 'complimentari', 'upgrad', 'first', 'class', 'avail', 'seat']
# ==========================================
# ['i', 'need', 'to', 'change', 'my', 'flight', 'thats', 'scheduled', 'in', 'hours', 'and', 'min', 'wait', 'time', 'on', 'phone']
# ['need', 'chang', 'flight', 'that', 'schedul', 'hour', 'min', 'wait', 'time', 'phone']
# ==========================================
# ['completely', 'awesome', 'experience', 'last', 'month', 'boslas', 'nonstop']
# ['complet', 'awesom', 'experi', 'last', 'month', 'bosla', 'nonstop']
# ==========================================
# ['how', 'can', 'i', 'watch', 'the', 'oscars', 'on', 'my', 'jfkgtsfo', 'flight']
# ['watch', 'oscar', 'jfkgtsfo', 'flight']
# ==========================================
# ['is', 'flight', 'cancelled', 'flightled', 'and', 'what', 'do', 'i', 'do', 'if', 'it', 'is']
# ['flight', 'cancel', 'flightl']
# ==========================================
# ['you', 'are', 'failing', 'your', 'customers', 'because', 'your', 'check', 'in', 'process', 'does', 'not', 'link', 'to', 'tsa', 'precheck']
# ['fail', 'custom', 'check', 'process', 'link', 'tsa', 'precheck']
# ==========================================
# ['us', 'too']
# ['us']
# ==========================================
# ['has', 'flight', 'number', 'from', 'sfo', 'to', 'cabo', 'san', 'lucas', 'arrived', 'yet']
# ['flight', 'number', 'sfo', 'cabo', 'san', 'luca', 'arriv', 'yet']
# ==========================================
# ['your', 'assistance', 'yesterday', 'when', 'u', 'cancelled', 'flightled', 'our', 'flight', 'was', 'to', 'give', 'us', 'a', 'hotel', 'hotline', 'shame', 'on', 'you']
# ['assist', 'yesterday', 'u', 'cancel', 'flightl', 'flight', 'give', 'us', 'hotel', 'hotlin', 'shame']
# ==========================================
# ['another', 'delayed', 'flight']
# ['anoth', 'delay', 'flight']
# ==========================================
# ['i', 'need', 'to', 'register', 'a', 'service', 'dog', 'for', 'a', 'first', 'class', 'ticket', 'from', 'sfo', 'gt', 'dulles']
# ['need', 'regist', 'servic', 'dog', 'first', 'class', 'ticket', 'sfo', 'gt', 'dull']
# ==========================================
# ['you', 'rock', 'for', 'making', 'it', 'so', 'i', 'can', 'watch', 'oscars', 'on', 'my', 'flight']
# ['rock', 'make', 'watch', 'oscar', 'flight']
# ==========================================
# ['dropped', 'a', 'track', 'on', 'you']
# ['drop', 'track']
# ==========================================
# ['always']
# ['alway']
# ==========================================
# ['why', 'cant', 'we', 'book', 'seats', 'on', 'your', 'flights', 'when', 'we', 'buy', 'them', 'or', 'even', 'during', 'check', 'in']
# ['cant', 'book', 'seat', 'flight', 'buy', 'even', 'check']
# ==========================================
# ['youd', 'think', 'paying', 'an', 'extra', 'bucks', 'rt', 'for', 'luggage', 'might', 'afford', 'you', 'hiring', 'an', 'extra', 'hand', 'at', 'lame']
# ['youd', 'think', 'pay', 'extra', 'buck', 'rt', 'luggag', 'might', 'afford', 'hire', 'extra', 'hand', 'lame']
# ==========================================
# ['best', 'customer', 'service', 'rep', 'in', 'the', 'world']
# ['best', 'custom', 'servic', 'rep', 'world']
# ==========================================
# ['can', 'you', 'find', 'us', 'a', 'flt', 'out', 'of', 'lax', 'that', 'is', 'sooner', 'than', 'midnight', 'on', 'monday']
# ['find', 'us', 'flt', 'lax', 'sooner', 'midnight', 'monday']
# ==========================================
# ['please', 'provide', 'status', 'for', 'flight']
# ['pleas', 'provid', 'status', 'flight']
# ==========================================
# ['you', 'have', 'amazing', 'staff', 'amp', 'super', 'helpful', 'as', 'i', 'just', 'ran', 'the', 'princesshalf', 'they', 'have', 'spoiled', 'me', 'with', 'comfort']
# ['amaz', 'staff', 'amp', 'super', 'help', 'ran', 'princesshalf', 'spoil', 'comfort']
# ==========================================
# ['i', 'paid', 'the', 'premium', 'to', 'fly', 'you', 'across', 'the', 'country', 'you', 'cancelled', 'flight', 'my', 'flight', 'and', 'offer', 'no', 'check', 'fee', 'or', 'upgrade', 'love']
# ['paid', 'premium', 'fli', 'across', 'countri', 'cancel', 'flight', 'flight', 'offer', 'check', 'fee', 'upgrad', 'love']
# ==========================================
# ['question', 'is', 'it', 'not', 'possible', 'to', 'book', 'a', 'seat', 'for', 'an', 'infant', 'under']
# ['question', 'possibl', 'book', 'seat', 'infant']
# ==========================================
# ['have', 'it', 'together']
# ['togeth']
# ==========================================
# ['flight', 'home', 'to', 'dc', 'sunset', 'globe', 'in', 'backtowinter', 'back', 'to', 'work']
# ['flight', 'home', 'dc', 'sunset', 'globe', 'backtowint', 'back', 'work']
# ==========================================
# ['i', 'dont', 'understand', 'why', 'you', 'need', 'a', 'dm', 'to', 'give', 'me', 'an', 'answer', 'on', 'if', 'you', 'have', 'a', 'damaged', 'luggage', 'policy']
# ['dont', 'understand', 'need', 'dm', 'give', 'answer', 'damag', 'luggag', 'polici']
# ==========================================
# ['does', 'that', 'mean', 'you', 'dont', 'have', 'a', 'policy', 'for', 'destroyed', 'luggage']
# ['mean', 'dont', 'polici', 'destroy', 'luggag']
# ==========================================
# ['is', 'there', 'special', 'assistance', 'if', 'i', 'travel', 'alone', 'w', 'kids', 'and', 'infant']
# ['special', 'assist', 'travel', 'alon', 'w', 'kid', 'infant']
# ==========================================
# ['thank', 'you', 'for', 'checking', 'in']
# ['thank', 'check']
# ==========================================
# ['is', 'your', 'website', 'ever', 'coming', 'back', 'online']
# ['websit', 'ever', 'come', 'back', 'onlin']
# ==========================================
# ['is', 'flight', 'from', 'love', 'field', 'to', 'sfo', 'definitely', 'cancelled', 'flightled', 'for', 'monday', 'february']
# ['flight', 'love', 'field', 'sfo', 'definit', 'cancel', 'flightl', 'monday', 'februari']
# ==========================================
# ['is', 'flight', 'out', 'of', 'lga', 'to', 'dfw', 'on', 'time']
# ['flight', 'lga', 'dfw', 'time']
# ==========================================
# ['my', 'drivers', 'license', 'is', 'expired', 'by', 'a', 'little', 'over', 'a', 'month']
# ['driver', 'licens', 'expir', 'littl', 'month']
# ==========================================
# ['having', 'problems', 'flight', 'booking', 'problems', 'on', 'the', 'web', 'site']
# ['problem', 'flight', 'book', 'problem', 'web', 'site']
# ==========================================
# ['how', 'do', 'i', 'reschedule', 'my', 'cancelled', 'flightled', 'flights', 'online']
# ['reschedul', 'cancel', 'flightl', 'flight', 'onlin']
# ==========================================
# ['i', 'rang', 'but', 'there', 'is', 'a', 'wait', 'for', 'minutes']
# ['rang', 'wait', 'minut']
# ==========================================
# ['got', 'a', 'flight', 'we', 'were', 'told', 'for', 'todaychecked', 'my', 'email', 'and', 'its', 'for', 'tomorrow']
# ['got', 'flight', 'told', 'todaycheck', 'email', 'tomorrow']
# ==========================================
# ['our', 'flight', 'into', 'lga', 'was', 'cancelled', 'flighted']
# ['flight', 'lga', 'cancel', 'flight']
# ==========================================
# ['why', 'dont', 'any', 'of', 'the', 'pairings', 'include', 'red', 'wine']
# ['dont', 'pair', 'includ', 'red', 'wine']
# ==========================================
# ['is', 'the', 'website', 'down']
# ['websit']
# ==========================================
# ['your', 'site', 'seems', 'a', 'little', 'wonked', 'right', 'now']
# ['site', 'seem', 'littl', 'wonk', 'right']
# ==========================================
# ['im', 'disappointed', 'that', 'the', 'agent', 'at', 'the', 'designated', 'silver', 'status', 'check', 'in', 'line', 'closed', 'to', 'assist', 'all', 'pasengers']
# ['im', 'disappoint', 'agent', 'design', 'silver', 'status', 'check', 'line', 'close', 'assist', 'paseng']
# ==========================================
# ['plans', 'to', 'include', 'austin', 'to', 'its', 'dallas', 'route', 'topnews', 'arab', 'emirates']
# ['plan', 'includ', 'austin', 'dalla', 'rout', 'topnew', 'arab', 'emir']
# ==========================================
# ['is', 'it', 'normal', 'to', 'receive', 'no', 'reply', 'from', 'central', 'baggage', 'baggageissues', 'smh']
# ['normal', 'receiv', 'repli', 'central', 'baggag', 'baggageissu', 'smh']
# ==========================================
# ['at', 'logan', 'airport', 'and', 'waiting', 'to', 'checkin', 'for', 'my', 'am', 'flight']
# ['logan', 'airport', 'wait', 'checkin', 'flight']
# ==========================================
# ['to', 'jump', 'into', 'the', 'dallasaustin', 'market']
# ['jump', 'dallasaustin', 'market']
# ==========================================
# ['beats', 'eps', 'views', 'takes', 'on', 'southwestair', 'va', 'luv', 'investors', 'business', 'daily']
# ['beat', 'ep', 'view', 'take', 'southwestair', 'va', 'luv', 'investor', 'busi', 'daili']
# ==========================================
# ['lister', 'to', 'my', 'show', 'my', 'on', 'monday']
# ['lister', 'show', 'monday']
# ==========================================
# ['to', 'begin', 'dallasaustin', 'flights', 'in', 'april', 'ketr']
# ['begin', 'dallasaustin', 'flight', 'april', 'ketr']
# ==========================================
# ['congrats', 'you', 'just', 'got', 'all', 'my', 'business', 'from', 'ewr', 'to', 'sfolax']
# ['congrat', 'got', 'busi', 'ewr', 'sfolax']
# ==========================================
# ['i', 'applied', 'over', 'weeks', 'ago']
# ['appli', 'week', 'ago']
# ==========================================
# ['id', 'love', 'to', 'know', 'what', 'your', 'policy', 'is', 'for', 'damaged', 'luggage']
# ['id', 'love', 'know', 'polici', 'damag', 'luggag']
# ==========================================
# ['thank', 'you', 'for', 'the', 'follow']
# ['thank', 'follow']
# ==========================================
# ['too', 'many', 'apologies']
# ['mani', 'apolog']
# ==========================================
# ['shame', 'on', 'va', 'for', 'making', 'people', 'spend', 'money', 'in', 'stranded', 'cities', 'when', 'other', 'airlines', 'are', 'landing', 'at', 'jfk']
# ['shame', 'va', 'make', 'peopl', 'spend', 'money', 'strand', 'citi', 'airlin', 'land', 'jfk']
# ==========================================
# ['i', 'dm', 'you']
# ['dm']
# ==========================================
# ['can', 'you', 'please', 'have', 'flights', 'in', 'sjc']
# ['pleas', 'flight', 'sjc']
# ==========================================
# ['too', 'bad', 'you', 'say', 'it', 'takes', 'to', 'days', 'via', 'your', 'confirmation', 'email']
# ['bad', 'say', 'take', 'day', 'via', 'confirm', 'email']
# ==========================================
# ['flight', 'from', 'bos', 'gt', 'las', 'tomorrow', 'was', 'cancelled', 'flightled']
# ['flight', 'bos', 'gt', 'las', 'tomorrow', 'cancel', 'flightl']
# ==========================================
# ['rt', 'youe', 'met', 'your', 'match']
# ['rt', 'youe', 'met', 'match']
# ==========================================
# ['only', 'way', 'to', 'fly']
# ['way', 'fli']
# ==========================================
# ['if', 'only', 'you', 'guys', 'had', 'flights', 'from', 'cmh']
# ['guy', 'flight', 'cmh']
# ==========================================
# ['a', 'lot', 'of', 'apologies', 'being', 'thrown', 'out', 'to', 'customers', 'from', 'what', 'i', 'can', 'seevery', 'sad']
# ['lot', 'apolog', 'thrown', 'custom', 'seeveri', 'sad']
# ==========================================
# ['for', 'all', 'my', 'flight', 'stuff', 'wrong', 'and', 'did', 'nothing', 'about', 'it']
# ['flight', 'stuff', 'wrong', 'noth']
# ==========================================
# ['having', 'an', 'issue', 'finding', 'a', 'missing', 'item', 'on', 'a', 'plane']
# ['issu', 'find', 'miss', 'item', 'plane']
# ==========================================
# ['you', 'will', 'match', 'my', 'americanairlines', 'status']
# ['match', 'americanairlin', 'status']
# ==========================================
# ['met', 'your', 'matchgot', 'status', 'on', 'another', 'airline']
# ['met', 'matchgot', 'status', 'anoth', 'airlin']
# ==========================================
# ['trying', 'to', 'book', 'a', 'flight', 'with', 'you', 'guys', 'and', 'your', 'website', 'wont', 'let', 'me', 'about', 'to', 'lose', 'my', 'business']
# ['tri', 'book', 'flight', 'guy', 'websit', 'wont', 'let', 'lose', 'busi']
# ==========================================
# ['you', 'suck']
# ['suck']
# ==========================================
# ['thanks']
# ['thank']
# ==========================================
# ['just', 'dmd']
# ['dmd']
# ==========================================
# ['because', 'we', 'never', 'recd', 'cancelled', 'flightlation', 'notice', 'we', 'were', 'left', 'w', 'no', 'options', 'to', 'fly', 'out', 'of', 'ps']
# ['never', 'recd', 'cancel', 'flightlat', 'notic', 'left', 'w', 'option', 'fli', 'ps']
# ==========================================
# ['trying', 'to', 'book', 'a', 'flight', 'amp', 'your', 'site', 'is', 'down']
# ['tri', 'book', 'flight', 'amp', 'site']
# ==========================================
# ['you', 'have', 'any', 'flights', 'flying', 'into', 'boston', 'tomorrow']
# ['flight', 'fli', 'boston', 'tomorrow']
# ==========================================
# ['you', 'stink']
# ['stink']
# ==========================================
# ['i', 'love', 'your', 'guys', 'song']
# ['love', 'guy', 'song']
# ==========================================
# ['your', 'website', 'is', 'down', 'and', 'im', 'trying', 'to', 'check', 'in']
# ['websit', 'im', 'tri', 'check']
# ==========================================
# ['done']
# ['done']
# ==========================================
# ['nervous', 'about', 'my', 'flight', 'from', 'dc', 'to', 'lax', 'getting', 'cancelled', 'flightled', 'tomorrow']
# ['nervous', 'flight', 'dc', 'lax', 'get', 'cancel', 'flightl', 'tomorrow']
# ==========================================
# ['cool', 'picture', 'of', 'another', 'virginamerica', 'plane', 'off', 'our', 'wing']
# ['cool', 'pictur', 'anoth', 'virginamerica', 'plane', 'wing']
# ==========================================
# ['keep', 'up', 'the', 'great', 'work']
# ['keep', 'great', 'work']
# ==========================================
# ['my', 'goodness', 'your', 'people', 'field', 'are', 'amazing', 'under', 'pressure', 'from', 'texas', 'beatstheothers', 'in', 'crisis', 'please', 'fly', 'me', 'to', 'ny']
# ['good', 'peopl', 'field', 'amaz', 'pressur', 'texa', 'beatstheoth', 'crisi', 'pleas', 'fli', 'ny']
# ==========================================
# ['thanks', 'for', 'a', 'great', 'flight', 'from', 'la', 'to', 'boston']
# ['thank', 'great', 'flight', 'la', 'boston']
# ==========================================
# ['can', 'you', 'please', 'get', 'me', 'to', 'the', 'new', 'york', 'area', 'before', 'monday', 'afternoon']
# ['pleas', 'get', 'new', 'york', 'area', 'monday', 'afternoon']
# ==========================================
# ['thanks', 'so', 'much', 'for', 'the', 'awesome', 'support', 'you', 'guys', 'rock']
# ['thank', 'much', 'awesom', 'support', 'guy', 'rock']
# ==========================================
# ['seats', 'in', 'row', 'dont', 'recline', 'should', 'mention', 'that', 'on', 'your', 'website', 'soreback']
# ['seat', 'row', 'dont', 'reclin', 'mention', 'websit', 'soreback']
# ==========================================
# ['flight', 'delayed', 'hours', 'in', 'la', 'due', 'to', 'mechanical', 'problems']
# ['flight', 'delay', 'hour', 'la', 'due', 'mechan', 'problem']
# ==========================================
# ['why', 'cancelled', 'flight', 'flights', 'today']
# ['cancel', 'flight', 'flight', 'today']
# ==========================================
# ['twitter', 'team']
# ['twitter', 'team']
# ==========================================
# ['you', 'guys', 'charged', 'me', 'to', 'reschedule', 'a', 'flight', 'that', 'was', 'then', 'cancelled', 'flighted', 'and', 'are', 'now', 'refusing', 'to', 'refund', 'it']
# ['guy', 'charg', 'reschedul', 'flight', 'cancel', 'flight', 'refus', 'refund']
# ==========================================
# ['can', 'access', 'your', 'website', 'from', 'safari', 'on', 'iphone']
# ['access', 'websit', 'safari', 'iphon']
# ==========================================
# ['on', 'ipad', 'and', 'iphone', 'clicking', 'the', 'checkin', 'link', 'in', 'the', 'email', 'i', 'received', 'at', 'hrs', 'before', 'flight']
# ['ipad', 'iphon', 'click', 'checkin', 'link', 'email', 'receiv', 'hrs', 'flight']
# ==========================================
# ['your', 'mobile', 'site', 'is', 'broken', 'shows', 'headerelevateusernumofpointsavailable', 'number', 'points', 'wont', 'let', 'me', 'checkin']
# ['mobil', 'site', 'broken', 'show', 'headerelevateusernumofpointsavail', 'number', 'point', 'wont', 'let', 'checkin']
# ==========================================
# ['i', 'was', 'really', 'looking', 'forward', 'to', 'my', 'flight']
# ['realli', 'look', 'forward', 'flight']
# ==========================================
# ['why', 'cancelled', 'flight', 'flight', 'vx']
# ['cancel', 'flight', 'flight', 'vx']
# ==========================================
# ['i', 'did', 'it', 'but', 'there', 'was', 'a', 'problem', 'in', 'the', 'link', 'from', 'the', 'email', 'for', 'checkin']
# ['problem', 'link', 'email', 'checkin']
# ==========================================
# ['had', 'to', 'change', 'to', 'another', 'airline', 'to', 'get', 'to', 'dc', 'today', 'why', 'is', 'able', 'to', 'land', 'in', 'dc', 'but', 'not', 'you']
# ['chang', 'anoth', 'airlin', 'get', 'dc', 'today', 'abl', 'land', 'dc']
# ==========================================
# ['i', 'was', 'so', 'looking', 'forward', 'to', 'my', 'first', 'flight', 'with', 'you', 'today', 'but', 'it', 'was', 'cancelled', 'flightled', 'along', 'with', 'the', 'subsequent', 'one']
# ['look', 'forward', 'first', 'flight', 'today', 'cancel', 'flightl', 'along', 'subsequ', 'one']
# ==========================================
# ['when', 'are', 'you', 'putting', 'some', 'great', 'deals', 'from', 'pdx', 'to', 'las', 'or', 'from', 'las', 'to', 'pdx', 'show', 'me', 'your', 'love']
# ['put', 'great', 'deal', 'pdx', 'las', 'las', 'pdx', 'show', 'love']
# ==========================================
# ['wish', 'i', 'can', 'afford', 'to', 'fly', 'with', 'you', 'next', 'friday', 'going', 'back', 'home', 'love', 'everything', 'about', 'your', 'airline']
# ['wish', 'afford', 'fli', 'next', 'friday', 'go', 'back', 'home', 'love', 'everyth', 'airlin']
# ==========================================
# ['how', 'are', 'you', 'gon', 'na', 'have', 'a', 'deal', 'from', 'dallas', 'to', 'dc', 'but', 'no', 'deal', 'from', 'dc', 'to', 'dallas']
# ['gon', 'na', 'deal', 'dalla', 'dc', 'deal', 'dc', 'dalla']
# ==========================================
# ['it', 'just', 'a', 'bug', 'report', 'guys']
# ['bug', 'report', 'guy']
# ==========================================
# ['hold', 'times', 'at', 'call', 'center', 'are', 'a', 'bit', 'much']
# ['hold', 'time', 'call', 'center', 'bit', 'much']
# ==========================================
# ['like']
# ['like']
# ==========================================
# ['site', 'down']
# ['site']
# ==========================================
# ['you', 'have', 'the', 'best', 'flight', 'attendant', 'ever']
# ['best', 'flight', 'attend', 'ever']
# ==========================================
# ['rt', 'watch', 'nominated', 'films', 'at', 'feet']
# ['rt', 'watch', 'nomin', 'film', 'feet']
# ==========================================
# ['thanks', 'so', 'much']
# ['thank', 'much']
# ==========================================
# ['trying', 'to', 'reset', 'my', 'password', 'email', 'never', 'arrives']
# ['tri', 'reset', 'password', 'email', 'never', 'arriv']
# ==========================================
# ['the', 'only', 'airline', 'based', 'in', 'silicon', 'valley']
# ['airlin', 'base', 'silicon', 'valley']
# ==========================================
# ['very', 'nicely', 'done']
# ['nice', 'done']
# ==========================================
# ['i', 'looking', 'forward', 'to', 'watching', 'the', 'oscars', 'on', 'my', 'flight', 'home', 'tomorrow']
# ['look', 'forward', 'watch', 'oscar', 'flight', 'home', 'tomorrow']
# ==========================================
# ['what', 'is', 'the', 'reason', 'for', 'the', 'delay', 'of', 'the', 'departure', 'of', 'vx', 'from', 'jfk', 'this', 'afternoon']
# ['reason', 'delay', 'departur', 'vx', 'jfk', 'afternoon']
# ==========================================
# ['is', 'todays', 'flight', 'from', 'palm', 'springs', 'ca', 'to', 'jfk', 'in', 'ny', 'cancelled', 'flightled']
# ['today', 'flight', 'palm', 'spring', 'ca', 'jfk', 'ny', 'cancel', 'flightl']
# ==========================================
# ['hahaha', 'you', 'guys', 'are', 'amazing']
# ['hahaha', 'guy', 'amaz']
# ==========================================
# ['sounds', 'like', 'fun']
# ['sound', 'like', 'fun']
# ==========================================
# ['any', 'updates', 'on', 'flight', 'from', 'jfk', 'gt', 'lax']
# ['updat', 'flight', 'jfk', 'gt', 'lax']
# ==========================================
# ['spruce', 'moose']
# ['spruce', 'moos']
# ==========================================
# ['the', 'css', 'on', 'your', 'site', 'is', 'a', 'right', 'now', 'please', 'fix']
# ['css', 'site', 'right', 'pleas', 'fix']
# ==========================================
# ['were', 'on', 'flight', 'vegas', 'to', 'boston', 'today', 'checked', 'in', 'online', 'but', 'our', 'bag', 'count', 'didnt', 'register']
# ['flight', 'vega', 'boston', 'today', 'check', 'onlin', 'bag', 'count', 'didnt', 'regist']
# ==========================================
# ['classiq', 'luv', 'virgin', 'america']
# ['classiq', 'luv', 'virgin', 'america']
# ==========================================
# ['hi', 'im', 'trying', 'to', 'do', 'checkin', 'but', 'the', 'website', 'is', 'not', 'working']
# ['hi', 'im', 'tri', 'checkin', 'websit', 'work']
# ==========================================
# ['thanks', 'for', 'your', 'great', 'customer', 'service', 'today', 'amp', 'for', 'helping', 'me', 'get', 'all', 'my', 'travel', 'sorted', 'out']
# ['thank', 'great', 'custom', 'servic', 'today', 'amp', 'help', 'get', 'travel', 'sort']
# ==========================================
# ['thanks', 'guys']
# ['thank', 'guy']
# ==========================================
# ['love', 'the', 's', 'music', 'blasting', 'at', 'gate', 'in', 'boston', 'while', 'waiting', 'for', 'flight', 'to', 'sanfrancisco']
# ['love', 'music', 'blast', 'gate', 'boston', 'wait', 'flight', 'sanfrancisco']
# ==========================================
# ['the', 'passenger', 'in', 'd', 'flt', 'that', 'assaulted', 'me', 'shouldnt', 'have', 'flown']
# ['passeng', 'flt', 'assault', 'shouldnt', 'flown']
# ==========================================
# ['current', 'bug', 'on', 'website', 'shows', 'elect', 'departure', 'city', 'when', 'selecting', 'destination', 'city']
# ['current', 'bug', 'websit', 'show', 'elect', 'departur', 'citi', 'select', 'destin', 'citi']
# ==========================================
# ['luggage', 'was', 'severely', 'dentedmissing', 'wheel', 'coming', 'off', 'baggage', 'claim', 'in', 'san']
# ['luggag', 'sever', 'dentedmiss', 'wheel', 'come', 'baggag', 'claim', 'san']
# ==========================================
# ['thank', 'you', 'for', 'the', 'easy', 'itinerary', 'shift', 'for', 'impending', 'weather']
# ['thank', 'easi', 'itinerari', 'shift', 'impend', 'weather']
# ==========================================
# ['if', 'youd', 'love', 'to', 'see', 'more', 'girls', 'be', 'inspired', 'to', 'become', 'pilots', 'rt', 'our', 'free', 'woaw', 'event', 'march', 'at', 'abq']
# ['youd', 'love', 'see', 'girl', 'inspir', 'becom', 'pilot', 'rt', 'free', 'woaw', 'event', 'march', 'abq']
# ==========================================
# ['thanks']
# ['thank']
# ==========================================
# ['beats', 'expectations', 'shares', 'take', 'off', 'santa', 'cruz', 'sentinel']
# ['beat', 'expect', 'share', 'take', 'santa', 'cruz', 'sentinel']
# ==========================================
# ['any', 'plans', 'to', 'start', 'flying', 'direct', 'from', 'dal', 'to', 'las']
# ['plan', 'start', 'fli', 'direct', 'dal', 'las']
# ==========================================
# ['big', 'lovegratitudempower', 'w', 'werin', 'oscars', 'vipswagbags', 'avalonhollywood']
# ['big', 'lovegratitudempow', 'w', 'werin', 'oscar', 'vipswagbag', 'avalonhollywood']
# ==========================================
# ['youre', 'doing', 'a', 'great', 'job', 'adding', 'little', 'luxuriesaesthetics', 'that', 'improve', 'the', 'air', 'travel', 'experience']
# ['your', 'great', 'job', 'ad', 'littl', 'luxuriesaesthet', 'improv', 'air', 'travel', 'experi']
# ==========================================
# ['requested', 'window', 'seat', 'and', 'confirmed', 'window', 'but', 'got', 'stuck', 'in', 'middle', 'seat']
# ['request', 'window', 'seat', 'confirm', 'window', 'got', 'stuck', 'middl', 'seat']
# ==========================================
# ['grand', 'budapest', 'hotel', 'oscarscountdown']
# ['grand', 'budapest', 'hotel', 'oscarscountdown']
# ==========================================
# ['this', 'is', 'what', 'you', 'missed']
# ['miss']
# ==========================================
# ['wtf', 'i', 'paid', 'for', 'direct', 'flight', 'on', 'purpose', 'not', 'to', 'have', 'to', 'stop', 'for', 'fuel', 'exhausted', 'frequent', 'flier', 'and', 'nothing', 'for', 'inconvenience']
# ['wtf', 'paid', 'direct', 'flight', 'purpos', 'stop', 'fuel', 'exhaust', 'frequent', 'flier', 'noth', 'inconveni']
# ==========================================
# ['there', 'is', 'something', 'wrong', 'with', 'you', 'website', 'in', 'safari', 'iphone']
# ['someth', 'wrong', 'websit', 'safari', 'iphon']
# ==========================================
# ['thanks', 'for', 'gate', 'checking', 'my', 'baggage', 'on', 'your', 'full', 'flight', 'dfwlax', 'and', 'giving', 'me', 'early', 'boarding', 'too', 'sweet']
# ['thank', 'gate', 'check', 'baggag', 'full', 'flight', 'dfwlax', 'give', 'earli', 'board', 'sweet']
# ==========================================
# ['already', 'checked', 'in', 'so', 'the', 'page', 'expired', 'x']
# ['alreadi', 'check', 'page', 'expir', 'x']
# ==========================================
# ['boo', 'for', 'a', 'not', 'refunding', 'a', 'seat', 'upgrade', 'fee', 'i', 'did', 'not', 'want', 'to', 'buy', 'in', 'the', 'first', 'place']
# ['boo', 'refund', 'seat', 'upgrad', 'fee', 'want', 'buy', 'first', 'place']
# ==========================================
# ['shares', 'rise', 'on', 'q', 'financial', 'results', 'usa', 'today']
# ['share', 'rise', 'q', 'financi', 'result', 'usa', 'today']
# ==========================================
# ['adds', 'pillows', 'instead', 'of', 'lieflat', 'seats', 'in', 'first', 'class', 'arms', 'race']
# ['add', 'pillow', 'instead', 'lieflat', 'seat', 'first', 'class', 'arm', 'race']
# ==========================================
# ['i', 'see', 'what', 'you', 'did', 'there']
# ['see']
# ==========================================
# ['way', 'to', 'take', 'advantage', 'of', 'mayweatherpacquiao']
# ['way', 'take', 'advantag', 'mayweatherpacquiao']
# ==========================================
# ['you', 'know', 'im', 'flying', 'virgin', 'for', 'the', 'fight', 'mayweatherpacquiao']
# ['know', 'im', 'fli', 'virgin', 'fight', 'mayweatherpacquiao']
# ==========================================
# ['your', 'inflight', 'team', 'makes', 'the', 'experience', 'amazing']
# ['inflight', 'team', 'make', 'experi', 'amaz']
# ==========================================
# ['cutest', 'salt', 'and', 'pepper', 'shaker', 'ever']
# ['cutest', 'salt', 'pepper', 'shaker', 'ever']
# ==========================================
# ['moved', 'my', 'seat', 'with', 'no', 'notice']
# ['move', 'seat', 'notic']
# ==========================================
# ['shares', 'up', 'on', 'q', 'results']
# ['share', 'q', 'result']
# ==========================================
# ['fav', 'airline']
# ['fav', 'airlin']
# ==========================================
# ['we', 'have', 'a', 'hot', 'female', 'pilot']
# ['hot', 'femal', 'pilot']
# ==========================================
# ['when', 'are', 'you', 'guys', 'going', 'to', 'start', 'flying', 'to', 'paris']
# ['guy', 'go', 'start', 'fli', 'pari']
# ==========================================
# ['what', 'is', 'your', 'policy', 'on', 'flying', 'after', 'surgery']
# ['polici', 'fli', 'surgeri']
# ==========================================
# ['already', 'contacted', 'central', 'baggage', 'amp', 'sent', 'dm']
# ...
# ==========================================
# ['tell', 'your', 'employees', 'that']
# ['tell', 'employe']
# ==========================================
# ['even', 'responded', 'quicker', 'via', 'twitter', 'when', 'they', 'fail']
# ['even', 'respond', 'quicker', 'via', 'twitter', 'fail']
# ==========================================
# ['ah', 'yes']
# ['ah', 'yes']
# ==========================================
# ['where', 'exactly', 'can', 'i', 'leave', 'a', 'note']
# ['exact', 'leav', 'note']
# ==========================================
# ['accepting', 'apple', 'pay', 'mobile', 'enterprise']
# ['accept', 'appl', 'pay', 'mobil', 'enterpris']
# ==========================================
# ['guys', 'really', 'bad', 'fail']
# ['guy', 'realli', 'bad', 'fail']
# ==========================================
# ['fail', 'my', 'wife', 'on', 'the', 'phone', 'asking', 'to', 'switch', 'flight', 'times']
# ['fail', 'wife', 'phone', 'ask', 'switch', 'flight', 'time']
# ==========================================
# ['thats', 'great']
# ['that', 'great']
# ==========================================
# ['they', 'tried', 'to', 'have', 'us', 'towed']
# ['tri', 'us', 'tow']
# ==========================================
# ['selfie', 'on', 'the', 'flight', 'from', 'jfk', 'to', 'orlando']
# ['selfi', 'flight', 'jfk', 'orlando']
# ==========================================
# ['ticket', 'issued', 'whilst', 'delivering', 'your', 'customers']
# ['ticket', 'issu', 'whilst', 'deliv', 'custom']
# ==========================================
# ['understand', 'that', 'but', 'this', 'policy', 'of', 'targeting', 'your', 'passengers', 'is', 'not', 'good', 'for', 'business', 'and', 'should', 'be', 'addressed', 'with', 'security']
# ['understand', 'polici', 'target', 'passeng', 'good', 'busi', 'address', 'secur']
# ==========================================
# ['been', 'a', 'fan', 'but', 'maybe', 'next', 'time', 'ill', 'fly', 'for', 'real', 'customer', 'service']
# ['fan', 'mayb', 'next', 'time', 'ill', 'fli', 'real', 'custom', 'servic']
# ==========================================
# ['i', 'agree']
# ['agre']
# ==========================================
# ['understood', 'but', 'could', 'i', 'go', 'and', 'put', 'myself', 'on', 'the', 'standby', 'list', 'hours', 'prior', 'to', 'my', 'flight']
# ['understood', 'could', 'go', 'put', 'standbi', 'list', 'hour', 'prior', 'flight']
# ==========================================
# ['the', 'whole', 'plane']
# ['whole', 'plane']
# ==========================================
# ['so', 'im', 'penalized', 'for', 'packing', 'lightly', 'having', 'bag', 'and', 'paying', 'extra', 'for', 'a', 'seat']
# ['im', 'penal', 'pack', 'light', 'bag', 'pay', 'extra', 'seat']
# ==========================================
# ['dropping', 'passengers', 'with', 'small', 'baby', 'and', 'infants', 'at', 'your', 'san', 'juan', 'terminal']
# ['drop', 'passeng', 'small', 'babi', 'infant', 'san', 'juan', 'termin']
# ==========================================
# ['the', 'tv']
# ['tv']
# ==========================================
# ['so', 'technically', 'i', 'could', 'drive', 'to', 'jfk', 'now', 'and', 'put', 'in']
# ['technic', 'could', 'drive', 'jfk', 'put']
# ==========================================
# ['why', 'did', 'i', 'pay', 'for', 'extra', 'space', 'to', 'be', 'forced', 'to', 'put', 'my', 'backpack', 'under', 'my', 'seat']
# ['pay', 'extra', 'space', 'forc', 'put', 'backpack', 'seat']
# ==========================================
# ['we', 'were', 'on', 'b', 'this', 'morning', 'from', 'boston', 'to', 'beautiful', 'san', 'diego']
# ['b', 'morn', 'boston', 'beauti', 'san', 'diego']
# ==========================================
# ['knew', 'that', 'has', 'to', 'be', 'done', 'at', 'the', 'gate', 'correct']
# ['knew', 'done', 'gate', 'correct']
# ==========================================
# ['philly', 'lost', 'and', 'read', 'program', 'our', 'customers', 'get', 'hot', 'tea', 'great', 'crewmembers', 'top', 'notch', 'info', 'amp', 'now', 'books']
# ['philli', 'lost', 'read', 'program', 'custom', 'get', 'hot', 'tea', 'great', 'crewmemb', 'top', 'notch', 'info', 'amp', 'book']
# ==========================================
# ['flight', 'njb', 'heres', 'looking', 'at', 'blue', 'kid', 'departs', 'enroute', 'to']
# ['flight', 'njb', 'here', 'look', 'blue', 'kid', 'depart', 'enrout']
# ==========================================
# ['punta', 'cana', 'to', 'enjoy', 'weather', 'n', 'see', 'my', 'wifes', 'family']
# ['punta', 'cana', 'enjoy', 'weather', 'n', 'see', 'wife', 'famili']
# ==========================================
# ['and', 'we', 'are', 'glad', 'to', 'see', 'what', 'is', 'going', 'on', 'and', 'fix']
# ['glad', 'see', 'go', 'fix']
# ==========================================
# ['just', 'lost', 'my', 'business', 'enjoy', 'your', 'profits']
# ['lost', 'busi', 'enjoy', 'profit']
# ==========================================
# ['i', 'would', 'drive', 'hours', 'to', 'jfk', 'to', 'board', 'jetblue', 'to', 'vegas', 'instead', 'of', 'closer', 'hartford', 'airport']
# ['would', 'drive', 'hour', 'jfk', 'board', 'jetblu', 'vega', 'instead', 'closer', 'hartford', 'airport']
# ==========================================
# ['name']
# ['name']
# ==========================================
# ['will', 'call']
# ['call']
# ==========================================
# ['yes', 'today']
# ['yes', 'today']
# ==========================================
# ['are', 'departing', 'flights', 'from', 'boston', 'heavily', 'delayed']
# ['depart', 'flight', 'boston', 'heavili', 'delay']
# ==========================================
# ['still', 'love', 'you', 'guys']
# ['still', 'love', 'guy']
# ==========================================
# ['gary', 'who', 'is', 'serving', 'us', 'at', 'fll', 'airport', 'counter', 'is', 'really', 'true', 'blue']
# ['gari', 'serv', 'us', 'fll', 'airport', 'counter', 'realli', 'true', 'blue']
# ==========================================
# ['is', 'there', 'no', 'way', 'to', 'switch', 'to', 'earlier', 'flight', 'to', 'jfk', 'even', 'if', 'i', 'checked', 'a', 'bag']
# ['way', 'switch', 'earlier', 'flight', 'jfk', 'even', 'check', 'bag']
# ==========================================
# ['this', 'is', 'not', 'a', 'flight', 'delay', 'this', 'is', 'horrible', 'planning', 'on', 'jet', 'blue']
# ['flight', 'delay', 'horribl', 'plan', 'jet', 'blue']
# ==========================================
# ['insane', 'the', 'craziness', 'ive', 'seen', 'with', 'jet', 'blue', 'today', 'at', 'newark', 'delayed', 'hours', 'and', 'now', 'we', 'are', 'waiting', 'for', 'a', 'pilot']
# ['insan', 'crazi', 'ive', 'seen', 'jet', 'blue', 'today', 'newark', 'delay', 'hour', 'wait', 'pilot']
# ==========================================
# ['hi']
# ['hi']
# ==========================================
# ['tried', 'again']
# ['tri']
# ==========================================
# ['so', 'happy', 'you', 'can', 'accommodate', 'peanuttreenut', 'allergies', 'on', 'flight']
# ['happi', 'accommod', 'peanuttreenut', 'allergi', 'flight']
# ==========================================
# ['always', 'happy', 'to', 'help']
# ['alway', 'happi', 'help']
# ==========================================
# ['we', 'have', 'just', 'landed', 'thank', 'you', 'anyway']
# ['land', 'thank', 'anyway']
# ==========================================
# ['we', 'are', 'delayed', 'until', 'he', 'arrives']
# ['delay', 'arriv']
# ==========================================
# ['the', 'highlight', 'of', 'being', 'delayed', 'freeconcert']
# ['highlight', 'delay', 'freeconcert']
# ==========================================
# ['whose', 'performing', 'at', 't']
# ['whose', 'perform']
# ==========================================
# ['is', 'it', 'only', 'for', 'my', 'nd', 'bag']
# ['nd', 'bag']
# ==========================================
# ['flight', 'first', 'officer', 'not', 'even', 'at', 'the', 'airport', 'wow']
# ['flight', 'first', 'offic', 'even', 'airport', 'wow']
# ==========================================
# ['ceo', 'battles', 'to', 'appease', 'passengers', 'and', 'wall', 'street']
# ['ceo', 'battl', 'appeas', 'passeng', 'wall', 'street']
# ==========================================
# ['why', 'does', 'my', 'tsapre', 'work', 'with', 'every', 'airline', 'but', 'you']
# ['tsapr', 'work', 'everi', 'airlin']
# ==========================================
# ['thats', 'right']
# ['that', 'right']
# ==========================================
# ['yes', 'times']
# ['yes', 'time']
# ==========================================
# ['pls', 'send', 'an', 'it', 'tech', 'baggage', 'office']
# ['pls', 'send', 'tech', 'baggag', 'offic']
# ==========================================
# ['you', 'take', 'to', 'me', 'places', 'simply', 'cantlike', 'nonstop', 'to', 'st', 'lucia']
# ['take', 'place', 'simpli', 'cantlik', 'nonstop', 'st', 'lucia']
# ==========================================
# ['flight', 'njb', 'blue', 'la', 'la', 'departs', 'enroute', 'to', 'san', 'juan', 'international', 'airport']
# ['flight', 'njb', 'blue', 'la', 'la', 'depart', 'enrout', 'san', 'juan', 'intern', 'airport']
# ==========================================
# ['this', 'makes', 'me', 'happy']
# ['make', 'happi']
# ==========================================
# ['dropped', 'x', 'in', 'past', 'hour']
# ['drop', 'x', 'past', 'hour']
# ==========================================
# ['i', 'want', 'to', 'work', 'on', 'the', 'jetblue', 'social', 'team', 'rt']
# ['want', 'work', 'jetblu', 'social', 'team', 'rt']
# ==========================================
# ['call', 'me', 'when', 'you', 'do', 'and', 'wel', 'have', 'to', 'hook', 'up']
# ['call', 'wel', 'hook']
# ==========================================
# ['ive', 'called', 'you', 'x', 'amp', 'waited', 'on', 'hold', 'min', 'each', 'time', 'to', 'be', 'disconnected', 'each', 'time']
# ['ive', 'call', 'x', 'amp', 'wait', 'hold', 'min', 'time', 'disconnect', 'time']
# ==========================================
# ['the', 'usa', 'help', 'line']
# ['usa', 'help', 'line']
# ==========================================
# ['if', 'you', 'have', 'wellpriced', 'flights', 'to', 'oahu', 'we', 'could', 'be', 'best', 'friends']
# ['wellpric', 'flight', 'oahu', 'could', 'best', 'friend']
# ==========================================
# ['we', 'dont', 'need', 'anybody', 'else']
# ['dont', 'need', 'anybodi', 'els']
# ==========================================
# ['any', 'idea', 'where', 'the', 'plane', 'for', 'flight', 'is', 'coming', 'from']
# ['idea', 'plane', 'flight', 'come']
# ==========================================
# ['its', 'for', 'me', 'i', 'spoke', 'with', 'a', 'rep', 'on', 'the', 'phone', 'who', 'suggested', 'i', 'voice', 'a', 'concern', 'via', 'email', 'us', 'on', 'your', 'site']
# ['spoke', 'rep', 'phone', 'suggest', 'voic', 'concern', 'via', 'email', 'us', 'site']
# ==========================================
# ['pls', 'find', 'my', 'bag', 'i', 'need', 'get', 'home']
# ['pls', 'find', 'bag', 'need', 'get', 'home']
# ==========================================
# ['tried', 'calling', 'multiple', 'times', 'i', 'just', 'wait', 'and', 'when', 'it', 'finally', 'connects', 'i', 'get', 'hung', 'up', 'on']
# ['tri', 'call', 'multipl', 'time', 'wait', 'final', 'connect', 'get', 'hung']
# ==========================================
# ['airways', 'sees', 'significant', 'drop', 'in', 'short', 'interest', 'jblu', 'mideast', 'time']
# ['airway', 'see', 'signific', 'drop', 'short', 'interest', 'jblu', 'mideast', 'time']
# ==========================================
# ['no', 'not', 'yet']
# ['yet']
# ==========================================
# ['thanks']
# ['thank']
# ==========================================
# ['dont', 'worry', 'im', 'gon', 'na', 'share', 'with', 'my', 'row']
# ['dont', 'worri', 'im', 'gon', 'na', 'share', 'row']
# ==========================================
# ['base', 'already']
# ['base', 'alreadi']
# ==========================================
# ['hold', 'for', 'min', 'a', 'couple', 'of', 'rings', 'then', 'mailbox', 'has', 'not', 'been', 'set', 'up', 'yet']
# ['hold', 'min', 'coupl', 'ring', 'mailbox', 'set', 'yet']
# ==========================================
# ['does', 'your', 'home', 'airport', 'not', 'count', 'in', 'the', 'badge', 'system']
# ['home', 'airport', 'count', 'badg', 'system']
# ==========================================
# ['is', 'bag', 'check', 'cut', 'off', 'minutes', 'before', 'the', 'original', 'departure', 'time', 'or', 'the', 'estimated', 'time', 'shown', 'online']
# ['bag', 'check', 'cut', 'minut', 'origin', 'departur', 'time', 'estim', 'time', 'shown', 'onlin']
# ==========================================
# ['i', 'know', 'where', 'you', 'guys', 'jet']
# ['know', 'guy', 'jet']
# ==========================================
# ['airways', 'adds', 'new', 'charter', 'flight', 'to', 'cuba', 'travel', 'wires', 'blog']
# ['airway', 'add', 'new', 'charter', 'flight', 'cuba', 'travel', 'wire', 'blog']
# ==========================================
# ['is', 'it']
# []
# ==========================================
# ['love', 'traveling', 'with', 'jetblue']
# ['love', 'travel', 'jetblu']
# ==========================================
# ['but', 'if', 'customer', 'service', 'ment', 'anything', 'to', 'you', 'you', 'would', 'try']
# ['custom', 'servic', 'ment', 'anyth', 'would', 'tri']
# ==========================================
# ['thank', 'you']
# ['thank']
# ==========================================
# ['thanks']
# ['thank']
# ==========================================
# ['are', 'we', 'good']
# ['good']
# ==========================================
# ['thanks', 'for', 'the', 'upgrade']
# ['thank', 'upgrad']
# ==========================================
# ['thank', 'you']
# ['thank']
# ==========================================
# ['this', 'could', 'be', 'the', 'beginning', 'of', 'a', 'bluetiful', 'relationship', 'lifeneedsfrosting']
# ['could', 'begin', 'blueti', 'relationship', 'lifeneedsfrost']
# ==========================================
# ['apparently', 'not']
# ['appar']
# ==========================================
# ['why', 'are', 'we', 'delayed', 'flight']
# ['delay', 'flight']
# ==========================================
# ['continue', 'button', 'generated', 'a', 'trip', 'to', 'plan', 'your', 'trip', 'page', 'regardless', 'of', 'how', 'far', 'along', 'i', 'was', 'in', 'flight', 'booking', 'problems', 'process', 'hint', 'the', 'end', 'of', 'it']
# ['continu', 'button', 'generat', 'trip', 'plan', 'trip', 'page', 'regardless', 'far', 'along', 'flight', 'book', 'problem', 'process', 'hint', 'end']
# ==========================================
# ['marks', 'th', 'birthday', 'with', 'a', 'painted', 'in', 'blumanity', 'paint', 'job']
# ['mark', 'th', 'birthday', 'paint', 'bluman', 'paint', 'job']
# ==========================================
# ['i', 'would', 'fly', 'to', 'washington', 'dc', 'to', 'see', 'the', 'actual', 'constitution', 'and', 'the', 'declaration', 'of', 'independence', 'in', 'honor', 'of', 'a', 'us', 'navy', 'friend']
# ['would', 'fli', 'washington', 'dc', 'see', 'actual', 'constitut', 'declar', 'independ', 'honor', 'us', 'navi', 'friend']
# ==========================================
# ['what', 'is', 'the', 'name', 'of', 'this', 'tailfin']
# ['name', 'tailfin']
# ==========================================
# ['new', 'ceo', 'robin', 'hayes', 'battles', 'to', 'appease', 'passengers', 'and', 'wall', 'street', 'business', 'in', 'savannah']
# ['new', 'ceo', 'robin', 'hay', 'battl', 'appeas', 'passeng', 'wall', 'street', 'busi', 'savannah']
# ==========================================
# ['wee', 'looking', 'for', 'our', 'next', 'flyingitforward', 'flier', 'from', 'dc', 'tell', 'us', 'where', 'youd', 'fly', 'amp', 'why']
# ['wee', 'look', 'next', 'flyingitforward', 'flier', 'dc', 'tell', 'us', 'youd', 'fli', 'amp']
# ==========================================
# ['haha', 'youre', 'doing', 'everything', 'right']
# ['haha', 'your', 'everyth', 'right']
# ==========================================
# ['thank', 'you']
# ['thank']
# ==========================================
# ['i', 'did', 'get', 'the', 'email']
# ['get', 'email']
# ==========================================
# ['i', 'applied', 'for', 'a', 'job', 'at', 'pdw', 'where', 'could', 'i', 'go', 'for', 'follow', 'up']
# ['appli', 'job', 'pdw', 'could', 'go', 'follow']
# ==========================================
# ['connecticut']
# ['connecticut']
# ==========================================
# ['i', 'would', 'fly', 'somewhere', 'hotter', 'then', 'here']
# ['would', 'fli', 'somewher', 'hotter']
# ==========================================
# ['great', 'smooth', 'flight', 'too']
# ['great', 'smooth', 'flight']

# %%
tweet_data.head()
# Out:
#    tweet_id sentiment        name  \
# 0         1   neutral     cairdin
# 1         2  positive    jnardino
# 2         3   neutral  yvonnalynn
# 3         4  negative    jnardino
# 4         5  negative    jnardino
#
#                                                 text   tweet_created  \
# 0                               What @dhepburn said.  24/02/15 11:35
# 1  plus you've added commercials to the experienc...  24/02/15 11:15
# 2  I didn't today... Must mean I need to take ano...  24/02/15 11:15
# 3  it's really aggressive to blast obnoxious "ent...  24/02/15 11:15
# 4           and it's a really big bad thing about it  24/02/15 11:14
#
#   tweet_location               user_timezone  \
# 0            NaN  Eastern Time (US & Canada)
# 1            NaN  Pacific Time (US & Canada)
# 2      Lets Play  Central Time (US & Canada)
# 3            NaN  Pacific Time (US & Canada)
# 4            NaN  Pacific Time (US & Canada)
#
#                                           sent_token
# 0                             [What @dhepburn said.]
# 1  [plus you've added commercials to the experien...
# 2  [I didn't today... Must mean I need to take an...
# 3  [it's really aggressive to blast obnoxious "en...
# 4         [and it's a really big bad thing about it]
