# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house_train = pd.read_csv(r"C:\Users\sanjiv\Documents\Datasets\Kaggle\House prices\train.csv")

# %%
house_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def summarise(df):
    print('=======================================================================================')
    print('||                                    Summary                                        ||')
    print('=======================================================================================')
    print('Rows:\t\t\t\t', df.shape[0], '\tColumns:\t\t\t\t',df.shape[1])
    print('Null Valued Columns:\t\t', df.isnull().nunique().sum())
    print('Null Valued > 80%:\t\t', ((df.isnull().sum().sort_values(ascending = False)*100/df.shape[0]) > 80).sum())

# %%
summarise(house_train)
# Out:
# ...
# ||                                    Summary                                        ||
# ...
# Rows:				 1460 	Columns:				 81
# Null Valued Columns:		 100
# Null Valued > 80%:		 4

# %%
Nulls = (house_train.isnull().sum().sort_values(ascending = False)*100/house_train.shape[0] ).to_frame()
Nulls.columns = ['Percentage']

# %%
Nulls.head()
# Out:
#              Percentage
# PoolQC        99.520548
# MiscFeature   96.301370
# Alley         93.767123
# Fence         80.753425
# FireplaceQu   47.260274

# %%
Nulls[Nulls['Percentage']>80]
# Out:
#              Percentage
# PoolQC        99.520548
# MiscFeature   96.301370
# Alley         93.767123
# Fence         80.753425

# %%
house_train.corr().style.background_gradient(cmap='YlGnBu').format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col0 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col1 {
#             background-color:  #b2e1b6;
#             color:  #000000;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col2 {
#             background-color:  #bbe4b5;
#             color:  #000000;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col3 {
#             background-color:  #f2fabc;
#             color:  #000000;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col4 {
#             background-color:  #ecf7b1;
#             color:  #000000;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col5 {
#             background-color:  #b4e2b6;
#             color:  #000000;
#         }    #T_81fbeca8_87a4_11ea_b1fa_96ca558a3334row0_col6 {
#             background-color:  #bbe4b5;
#             color:  #000000;
# ...

# %%
house_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_train['SalePrice'].hist()

# %%
import seaborn as sns

# %%
sns.boxplot(house_train['SalePrice'])

# %%
house_train['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %% [markdown]
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
